# %%
# !pip install hazm
from hazm import *
import nltk
nltk.download('wordnet')
# Out:
# ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
sent_tokenize("سلام! به ورکشاپ پردازش زبان طبیعی خوش آمدید. از اعتماد شما به گروه آموزشی  متشکریم")
# Out:
# ['سلام!',
#  'به ورکشاپ پردازش زبان طبیعی خوش آمدید.',
#  'از اعتماد شما به گروه آموزشی  متشکریم']

# %%
word_tokenize("سلام! به ورکشاپ پردازش زبان طبیعی خوش آمدید. از اعتماد شما به گروه آموزشی  متشکریم")
# Out:
# ['سلام',
#  '!',
#  'به',
#  'ورکشاپ',
#  'پردازش',
#  'زبان',
#  'طبیعی',
#  'خوش',
#  'آمدید',
#  '.',
#  'از',
#  'اعتماد',
#  'شما',
#  'به',
#  'گروه',
#  'آموزشی',
#  'متشکریم']

# %%
stemmer=Stemmer()
stemmer.stem("کتاب‌ها")
# Out:
# 'کتاب'

# %%
stemmer=Stemmer()
stemmer.stem("آمدیم")
# Out:
# 'آمد'

# %%
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("تگها")
# Out:
# 'تگها'

# %%
lemmatizer.lemmatize("سلام! به ورکشاپ پردازش زبان طبیعی خوش آمدید. از اعتماد شما به گروه آموزشی  متشکریم")
# Out:
# 'سلام! به ورکشاپ پردازش زبان طبیعی خوش آمدید. از اعتماد شما به گروه آموزشی  متشکریم'

# %%
lemmatizer = Lemmatizer()
lemmatizer.lemmatize('می‌روم')
# Out:
# 'رفت#رو'

# %%
lemmatizer = Lemmatizer()
lemmatizer.lemmatize("گفته شده است")
# Out:
# 'گفت#گو'
